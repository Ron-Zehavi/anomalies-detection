# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import eif
from kando import kando_client
import pickle
# %run utils.ipynb
# import libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest

# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d   

from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from keras.models import Model
from keras import regularizers

import eif as iso

# %%
WINDOW = 24

# %% [markdown]
# <div class="alert alert-info"><b>&emsp;<u>LOAD the DATA </u></b>
#
# **DF** - preprocessed data:  <br>
# &emsp;data was taken from 2020 <br>
# &emsp;outliers were replaced with mean <br>
# &emsp;null were imputed with interpolations (X axis is time) <br>
# **mp** - matrix profile calculation: <br>
# &emsp;calculated for each measurement individually and for all dimensions together  <br>
# &emsp;window size 24 <br>
# **active_by_authority** <br>
# &emsp;dictionary keys - authority code <br>
# &emsp;dictionary values - dictionary with 2 keys: <br>
# &emsp;&emsp;authority name : value - name <br>
# &emsp;&emsp;nodes : all points id that were active in 2020

# %%
mps = load_point_mps(883)

# %%
df = load_point_data(883)

# %%
with open('water_authority.json') as f:
    active_by_aouthority = json.load(f)

# %% [markdown]
# ## MATRIX PROFILE ANOMALIES

# %%
df = add_matrix_profile_anomalies_labels(df, mps)
# Out:
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
plot__matrix_profile_anomalies(df)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <div class="alert alert-info"><b>&emsp;<u>ISOLATION FOREST ANOMALIES </u></b>

# %%
df = add_isolation_forest_anomalies_labels(df)
# Out:
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plot__isolation_forest_anomalies(df)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <div class="alert alert-info"><b>&emsp;<u>AUTOENCODER ANOMALIES </u></b>

# %%
def vae_input_preprocessing(df):
        # normalize the data
    x = df[['EC', 'PH', 'ORP', 'TEMPERATURE']].values  #returns a numpy array
    min_max_scaler = MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)

        # reshape inputs for LSTM [samples, timesteps, features]
    vae_input = x_scaled.reshape(x_scaled.shape[0], 1, x_scaled.shape[1])
    return(vae_input)

# %%
# define the autoencoder network model

def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
def add_vae_anomalies_labels(df, model):

    X_pred = model.predict(vae_input)
    X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
    X_pred = pd.DataFrame(X_pred, columns=['EC', 'PH', 'ORP', 'TEMPERATURE'])
    X_pred.index = df.index

    Xtrain = vae_input.reshape(vae_input.shape[0], vae_input.shape[2])

    scored_train = pd.DataFrame(index=df.index)
    scored_train['Loss_mae'] = np.mean(np.abs(X_pred - Xtrain), axis=1)

    df['auto encoder Anomaly'] = 0
    df['auto encoder Anomaly'][scored_train['Loss_mae'].nlargest(
        n=WINDOW, keep='first').index] = 1
    return (df)

# %%
def plot_vae_anomalies(df):

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    for i in range(2):
        x = df['PH'][df['auto encoder Anomaly'] == i]
        y = df['EC'][df['auto encoder Anomaly'] == i]
        z = df['TEMPERATURE'][df['auto encoder Anomaly'] == i]

        if i == 0:
            tmp_size = 90
            tmp_alpha = 0.05
            tmp_edgecolor = None
            color = 'blue'
            label = 'NORMAL'
            marker = '.'
        else:
            tmp_size = 130
            tmp_alpha = 0.8
            tmp_edgecolor = 'black'
            color = 'black'
            label = 'ALL DIMS'
            marker = '*'


        scatter = ax.scatter(x,
                             y,
                             z,
                             c=color,
                             marker=marker,
                             cmap=plt.cm.Spectral_r,
                             alpha=tmp_alpha,
                             s=tmp_size,
                             edgecolor=tmp_edgecolor,
                             label=label)
    plt.legend(title=' TYPE')

    ax.set_xlabel('PH')
    ax.set_ylabel('EC')
    ax.set_zlabel('TEMPERATURE')

    plt.title('AUTO ENCODER ANOMALIES\n', FontSize=16, FontWeight='bold')

    plt.show()

# %%
vae_input = vae_input_preprocessing(df)

# create the autoencoder model

model = autoencoder_model(vae_input)
model.compile(optimizer='adam', loss='mae' , metrics=['accuracy'])
model.summary()

# fit the model to the data

nb_epochs = 100
batch_size = WINDOW
history = model.fit(vae_input, vae_input, epochs=nb_epochs, batch_size=batch_size,
                    validation_split=0.15).history

df = add_vae_anomalies_labels(df, model)
plot_vae_anomalies(df)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1, 4)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1344
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 4)              68
# =================================================================
# Total params: 3,236
# Trainable params: 3,236
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1900/1900 [==============================] - 13s 7ms/step - loss: 0.0890 - accuracy: 0.6957 - val_loss: 0.0652 - val_accuracy: 0.9990
# Epoch 2/100
# 1900/1900 [==============================] - 10s 5ms/step - loss: 0.0565 - accuracy: 0.8227 - val_loss: 0.0606 - val_accuracy: 0.9990
# Epoch 3/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0485 - accuracy: 0.8738 - val_loss: 0.0393 - val_accuracy: 0.9985
# Epoch 4/100
# 1900/1900 [==============================] - 8s 4ms/step - loss: 0.0323 - accuracy: 0.9424 - val_loss: 0.0430 - val_accuracy: 0.9990
# Epoch 5/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0308 - accuracy: 0.9435 - val_loss: 0.0426 - val_accuracy: 0.9990
# Epoch 6/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0298 - accuracy: 0.9444 - val_loss: 0.0407 - val_accuracy: 0.9990
# Epoch 7/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0269 - accuracy: 0.9451 - val_loss: 0.0323 - val_accuracy: 0.9990
# Epoch 8/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0190 - accuracy: 0.9739 - val_loss: 0.0252 - val_accuracy: 0.9990
# Epoch 9/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0167 - accuracy: 0.9796 - val_loss: 0.0220 - val_accuracy: 0.9990
# Epoch 10/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0149 - accuracy: 0.9845 - val_loss: 0.0161 - val_accuracy: 0.9986
# Epoch 11/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0138 - accuracy: 0.9870 - val_loss: 0.0151 - val_accuracy: 0.9961
# Epoch 12/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0133 - accuracy: 0.9886 - val_loss: 0.0137 - val_accuracy: 0.9974
# Epoch 13/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0130 - accuracy: 0.9897 - val_loss: 0.0132 - val_accuracy: 0.9959
# Epoch 14/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0128 - accuracy: 0.9907 - val_loss: 0.0124 - val_accuracy: 0.9971
# Epoch 15/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0126 - accuracy: 0.9914 - val_loss: 0.0118 - val_accuracy: 0.9974
# Epoch 16/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0125 - accuracy: 0.9915 - val_loss: 0.0116 - val_accuracy: 0.9971
# Epoch 17/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0124 - accuracy: 0.9920 - val_loss: 0.0124 - val_accuracy: 0.9961
# Epoch 18/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0124 - accuracy: 0.9925 - val_loss: 0.0112 - val_accuracy: 0.9973
# Epoch 19/100
# 1900/1900 [==============================] - 7s 3ms/step - loss: 0.0123 - accuracy: 0.9927 - val_loss: 0.0111 - val_accuracy: 0.9976
# Epoch 20/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0123 - accuracy: 0.9927 - val_loss: 0.0106 - val_accuracy: 0.9978
# Epoch 21/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0122 - accuracy: 0.9927 - val_loss: 0.0106 - val_accuracy: 0.9976
# Epoch 22/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0122 - accuracy: 0.9931 - val_loss: 0.0114 - val_accuracy: 0.9970
# Epoch 23/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0121 - accuracy: 0.9930 - val_loss: 0.0102 - val_accuracy: 0.9979
# Epoch 24/100
# 1900/1900 [==============================] - 8s 4ms/step - loss: 0.0121 - accuracy: 0.9932 - val_loss: 0.0121 - val_accuracy: 0.9971
# Epoch 25/100
# 1900/1900 [==============================] - 11s 6ms/step - loss: 0.0121 - accuracy: 0.9931 - val_loss: 0.0118 - val_accuracy: 0.9979
# Epoch 26/100
# 1900/1900 [==============================] - 11s 6ms/step - loss: 0.0121 - accuracy: 0.9933 - val_loss: 0.0106 - val_accuracy: 0.9979
# Epoch 27/100
# 1900/1900 [==============================] - 11s 6ms/step - loss: 0.0120 - accuracy: 0.9934 - val_loss: 0.0110 - val_accuracy: 0.9981
# Epoch 28/100
# 1900/1900 [==============================] - 11s 6ms/step - loss: 0.0120 - accuracy: 0.9935 - val_loss: 0.0131 - val_accuracy: 0.9978
# Epoch 29/100
# 1900/1900 [==============================] - 11s 6ms/step - loss: 0.0120 - accuracy: 0.9936 - val_loss: 0.0104 - val_accuracy: 0.9981
# Epoch 30/100
# 1900/1900 [==============================] - 10s 5ms/step - loss: 0.0119 - accuracy: 0.9941 - val_loss: 0.0103 - val_accuracy: 0.9984
# Epoch 31/100
# 1900/1900 [==============================] - 7s 4ms/step - loss: 0.0119 - accuracy: 0.9939 - val_loss: 0.0102 - val_accuracy: 0.9981
# Epoch 32/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0119 - accuracy: 0.9940 - val_loss: 0.0097 - val_accuracy: 0.9985
# Epoch 33/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0119 - accuracy: 0.9937 - val_loss: 0.0104 - val_accuracy: 0.9981
# Epoch 34/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0118 - accuracy: 0.9941 - val_loss: 0.0105 - val_accuracy: 0.9984
# Epoch 35/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0118 - accuracy: 0.9944 - val_loss: 0.0096 - val_accuracy: 0.9986
# Epoch 36/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0118 - accuracy: 0.9946 - val_loss: 0.0104 - val_accuracy: 0.9990
# Epoch 37/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0117 - accuracy: 0.9946 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 38/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9949 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 39/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9947 - val_loss: 0.0100 - val_accuracy: 0.9990
# Epoch 40/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 41/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9951 - val_loss: 0.0105 - val_accuracy: 0.9990
# Epoch 42/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9953 - val_loss: 0.0095 - val_accuracy: 0.9990
# Epoch 43/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 0.0098 - val_accuracy: 0.9990
# Epoch 44/100
# 1900/1900 [==============================] - 5s 2ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 0.0092 - val_accuracy: 0.9990
# Epoch 45/100
# 1900/1900 [==============================] - 7s 4ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 46/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.0089 - val_accuracy: 0.9990
# Epoch 47/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 0.0090 - val_accuracy: 0.9990
# Epoch 48/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 49/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 50/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0108 - val_accuracy: 0.9990
# Epoch 51/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0091 - val_accuracy: 0.9990
# Epoch 52/100
# 1900/1900 [==============================] - 5s 2ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 53/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 54/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0095 - val_accuracy: 0.9990
# Epoch 55/100
# 1900/1900 [==============================] - 4s 2ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0091 - val_accuracy: 0.9990
# Epoch 56/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0090 - val_accuracy: 0.9990
# Epoch 57/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0106 - val_accuracy: 0.9990
# Epoch 58/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0090 - val_accuracy: 0.9990
# Epoch 59/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0098 - val_accuracy: 0.9990
# Epoch 60/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 61/100
# 1900/1900 [==============================] - 5s 2ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 62/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 63/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0099 - val_accuracy: 0.9990
# Epoch 64/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0087 - val_accuracy: 0.9990
# Epoch 65/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 66/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.0098 - val_accuracy: 0.9990
# Epoch 67/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 68/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 69/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 70/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0098 - val_accuracy: 0.9990
# Epoch 71/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0100 - val_accuracy: 0.9990
# Epoch 72/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0101 - val_accuracy: 0.9990
# Epoch 73/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 74/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 75/100
# 1900/1900 [==============================] - 5s 2ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 76/100
# 1900/1900 [==============================] - 4s 2ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0094 - val_accuracy: 0.9990
# Epoch 77/100
# 1900/1900 [==============================] - 4s 2ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 78/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0086 - val_accuracy: 0.9990
# Epoch 79/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.0098 - val_accuracy: 0.9990
# Epoch 80/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 81/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.0104 - val_accuracy: 0.9990
# Epoch 82/100
# 1900/1900 [==============================] - 5s 3ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0088 - val_accuracy: 0.9990
# Epoch 83/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.0105 - val_accuracy: 0.9990
# Epoch 84/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0103 - val_accuracy: 0.9990
# Epoch 85/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0091 - val_accuracy: 0.9990
# Epoch 86/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 87/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0089 - val_accuracy: 0.9990
# Epoch 88/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0095 - val_accuracy: 0.9990
# Epoch 89/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 90/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.0103 - val_accuracy: 0.9990
# Epoch 91/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0099 - val_accuracy: 0.9990
# Epoch 92/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0103 - val_accuracy: 0.9990
# Epoch 93/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0092 - val_accuracy: 0.9990
# Epoch 94/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 95/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 96/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0090 - val_accuracy: 0.9990
# Epoch 97/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0085 - val_accuracy: 0.9990
# Epoch 98/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0093 - val_accuracy: 0.9990
# Epoch 99/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0084 - val_accuracy: 0.9990
# Epoch 100/100
# 1900/1900 [==============================] - 6s 3ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0083 - val_accuracy: 0.9990
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <div class="alert alert-info"><b><u><center>EXTENDED ISOLATION FOREST ANOMALIES </center></u></b>

# %%
def add_extended_isolation_forest_anomalies_labels(df):
    # normalize the data
    x = df[['EC', 'PH', 'ORP', 'TEMPERATURE']].values  #returns a numpy array
    min_max_scaler = MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)

    if_eif = iso.iForest(x_scaled,
                         ntrees=100,
                         sample_size=256,
                         ExtensionLevel=3)

    # calculate anomaly scores
    anomaly_scores = if_eif.compute_paths(X_in=x_scaled)
    max_indices = anomaly_scores.argsort()[-WINDOW:][::-1]
    df['ALL_DIMS_eif'] = 0
    df['ALL_DIMS_eif'][max_indices] = 1
    
    indx = np.arange(df.shape[0])
    for col in ['EC', 'PH', 'ORP', 'TEMPERATURE']:
        df[f'{col}_eif'] = 0
        values = df[col].values
        tempdf = pd.DataFrame({
            'time': indx,
            'ph': values,
        })
        anomaly_score = iso.iForest(tempdf.values, 
                         ntrees = 100, 
                         sample_size = 256, 
                         ExtensionLevel = 1)
        anomaly_scores = if_eif.compute_paths(X_in = tempdf.values)
        max_indices = anomaly_scores.argsort()[-WINDOW:][::-1]
        df[f'{col}_eif'][max_indices] = 1

    df['NORMAL_eif'] = 1
    df['NORMAL_eif'][(df['EC_eif'] == 1) | (df['PH_eif'] == 1) | (df['ORP_eif'] == 1) |
                    (df['TEMPERATURE_eif'] == 1) | (df['ALL_DIMS_eif'] == 1)] = 0
    return (df)

# %%
def plot_extended_isolation_forest(df):

    eif_cols = ['NORMAL_eif', 'ALL_DIMS_eif', 'EC_eif', 'PH_eif', 'ORP_eif', 'TEMPERATURE_eif', ]
    colors = ['blue', 'black', 'red', 'green', 'yellow', 'orange']
    labels = ['NORMAL', 'ALL DIMS', 'EC', 'PH', 'ORP', 'TEMPERATURE']

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    for i in range(6):
        x = df['PH'][df[eif_cols[i]] == 1]
        y = df['EC'][df[eif_cols[i]] == 1]
        z = df['TEMPERATURE'][df[eif_cols[i]] == 1]

        tmp_color = colors[i]
        if i == 0:
            tmp_size = 90
            tmp_alpha = 0.03
            tmp_edgecolor = None
            marker = '.'
        else:
            tmp_size = 130
            tmp_alpha = 0.8
            tmp_edgecolor = 'black'
            marker = '*'

        scatter = ax.scatter(x,
                             y,
                             z,
                             c=colors[i],
                             marker=marker,
                             cmap=plt.cm.Spectral_r,
                             alpha=tmp_alpha,
                             s=tmp_size,
                             edgecolor=tmp_edgecolor,
                             label=labels[i])
    plt.legend(title=' TYPE')

    ax.set_xlabel('PH')
    ax.set_ylabel('EC')
    ax.set_zlabel('TEMPERATURE')

    plt.title('EXTENDED ISOLATION FOREST ANOMALIES\n', FontSize=16, FontWeight='bold')

    plt.show()

# %%
plot_extended_isolation_forest(df)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
df = add_extended_isolation_forest_anomalies_labels(df)
plot_extended_isolation_forest(df)
# Out:
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/ron/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="1000">

# %%
def save_df_with_anomalies(df, point_id):
    b_file = open(f"{point_id}_data_with_anomalies.pkl", "wb")
    pickle.dump(df, b_file)
    b_file.close()

# %%
save_df_with_anomalies(df, 911)
