# %%
from matplotlib import pyplot as plt
import json
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
import stumpy
import matplotlib.dates as dates
from matplotlib.patches import Rectangle
import datetime as dt
from collections import Counter
import urllib
import ssl
from tqdm.notebook import tqdm
import io
import os
from kando import kando_client
# %run utils.ipynb

# %%
with open('key.json') as f:
    api_login = json.load(f)

url = "https://kando-staging.herokuapp.com"
client = kando_client.client(url, api_login['key'], api_login['secret'])

# %%
RESAMPLE = '15min'
WINDOW = 12
THRESHOLD = 0.05
POINT_ID = 1377

# %%
def _parser(node, graph):
    # recursively build graph from end node
    if len(node['children']) == 0:
        graph.add_node(node['point_id'], name=node['point']['name'])
        return
    for child in node['children']:
        graph.add_edges_from([(node['point_id'], child['point_id'])],
                             weight=child['parent_distance'])
        _parser(child, graph)


def get_graph(point_id):
    g = client.network_graph(point_id)
    G = nx.DiGraph()
    _parser(g, G)
    return G.reverse(
    )  # we reverse because "children" in API are parents in NetworkX terms

# %%
import json
import networkx as nx

# %%
G = get_graph(1012)
# Out:
# Kando - GET /api/data/network_graph?point_id=1012

# %%
gichon_nodes = nx.get_node_attributes(G, 'name')

# %%
gichon_nodes
# Out:
# {2045: 'מאסף שורק ישן',
#  941: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  963: 'תעשייתי',
#  1159: 'אחוד',
#  1056: 'אחוד',
#  1087: 'אחוד',
#  1133: 'אחוד',
#  1088: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1134: 'אחוד',
#  1130: 'אחוד',
#  1085: 'אחוד',
#  1061: 'אחוד',
#  1238: 'שוחה אחרונה',
#  1062: 'אחוד',
#  1531: 'כוללת',
#  1127: 'אחוד',
#  1164: 'אחוד',
#  1076: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  990: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  966: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  999: 'תעשייתי',
#  1111: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1078: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1023: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1057: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1155: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1530: 'חיצונית כוללת',
#  933: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  987: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  977: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1917: 'מאסף',
#  898: 'תעשייתי',
#  1989: 'בניין מכון התקנים',
#  1461: 'סיגמה חיצוני',
#  889: 'תעשייתית',
#  1520: 'מאסף חיצוני',
#  901: 'תעשייתי',
#  1355: 'קפס פארמה כניסה',
#  1359: 'הר חוצבים צפון מזרחי הרב פלקסר',
#  1338: 'בקר חיצוני למפעל',
#  1339: 'בקר',
#  1545: 'ליפתא',
#  1533: 'בקר מחוץ למפעל',
#  1333: 'מאסף כפר עקב 2',
#  1208: 'מאסף',
#  995: 'תעשייתי',
#  907: 'תעשייתי',
#  961: 'תעשייתי',
#  1561: 'מאספת',
#  895: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  897: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  921: 'תעשייתי',
#  1332: 'מאסף כפר עקב 1',
#  910: 'תעשייתי',
#  985: 'קו ראשי פעיל',
#  1584: 'בקר',
#  1191: 'ביציאה מהמשחטה',
#  916: 'תעשייתי',
#  931: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  927: 'תעשייתי',
#  1354: 'פרמנטק ניפל עליון',
#  905: 'תעשייתי',
#  903: 'תעשייתי',
#  890: 'תעשייתי',
#  896: 'שוחה אחרונה',
#  1192: 'חיצונית ממול לשער כניסה ',
#  913: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  893: 'תעשייתי',
#  908: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  2385: 'הר נוף',
#  1104: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  3436: 'בית ג׳אלה COD',
#  955: 'קו מאסף בית גאלה',
#  1080: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1356: 'גבעת רם',
#  1372: 'בקר',
#  1033: 'אחוד',
#  1373: 'בקר רמדה ',
#  1991: 'שוחה אחרונה צד דרומי',
#  997: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  888: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1032: 'אחוד',
#  1069: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  902: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1098: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  3256: 'מאספת',
#  1490: 'אקווריום שוחה חיצונית',
#  1048: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1029: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1035: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1065: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1028: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1041: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1137: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1125: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1042: 'אחוד',
#  1045: 'אחוד',
#  904: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  2391: 'בית צפאפא',
#  1047: 'אחוד',
#  1055: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1145: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  924: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  2387: 'גבעת משואה',
#  1135: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוניhttps://kando.herokuapp.com/groups/963/edit?locale=en&water_authority_id=24#manhole-hierarchy-tab',
#  906: 'תעשייתי',
#  1560: 'מלון נופים',
#  911: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1072: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1103: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1107: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1024: 'אחוד',
#  1039: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1044: 'אחוד',
#  1052: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1034: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1149: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1146: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1138: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1082: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1091: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1074: 'שוחה אחרונה לפני הזרמת השפכים לביוב העירוני',
#  1112: 'אחוד'}

# %%
mifal = {k:v for k,v in gichon_nodes.items() if client.get_data(k)['point']['group']['sector']['name'] == 'Main Collector*'}
# Out:
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=941&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=963&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1159&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1056&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1087&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1133&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1088&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1134&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1130&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1085&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1061&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1238&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1062&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1531&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1127&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1164&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1076&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=990&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=966&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=999&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1111&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1078&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1023&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1057&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1155&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1530&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=933&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=987&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=977&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1917&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=898&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1989&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1461&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=889&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1520&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=901&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1355&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1359&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1338&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1339&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1545&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1533&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1208&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=995&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=907&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=961&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=895&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=897&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=921&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=910&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=985&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1584&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1191&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=916&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=931&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=927&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1354&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=905&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=903&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=890&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=896&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1192&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=913&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=893&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=908&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2385&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=3436&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=955&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1080&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1356&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1033&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1373&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1991&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=997&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=888&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1032&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1069&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=902&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1098&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=3256&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1490&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1048&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1029&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1035&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1065&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1028&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1041&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1137&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1125&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1042&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1045&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=904&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2391&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1047&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1055&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1145&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=924&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2387&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1135&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=906&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1560&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1072&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1103&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1107&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1024&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1039&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1044&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1052&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1034&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1149&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1146&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1138&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1082&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1091&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1074&unit_id=&start=&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1112&unit_id=&start=&end=&raw_data=

# %%
collectors = list(mifal.keys())
collectors
# Out:
# [2045, 1531, 1545, 1333, 1561, 1332, 2385, 2391, 2387]

# %%
def create_sectorial_dataframe(sites_list, start_date=2016):
    for i, site in tqdm(enumerate(sites_list)):
        print(f'getting info from {site}')
        site_dic = client.get_all(point_id=site, start=start_date)            
        if len(site_dic['samplings'])>0:
            print(f'creating a dataframe')
            sector_tmp = get_data_for_sectorial_motif_detection(site_dic)
            print(f'adding datafram to the sectorial dataframe')
            if i==0:
                sector = sector_tmp
            else:
                sector = pd.concat([sector, sector_tmp])
        else:
            print(f'No data about site {site}')
    sector.reset_index(drop=True, inplace=True)
    return sector

# %%
def get_data_for_sectorial_motif_detection(site_dic):

    df = pd.DataFrame.from_dict(site_dic['samplings'], orient='index')[[
        'DateTime', 'PH', 'EC', 'ORP', 'TEMPERATURE'
    ]]
    df['date'] = df['DateTime']
    df['DateTime'] = pd.to_datetime(df['DateTime'], unit='s')
    df = df.set_index('DateTime')

    impute_nulls_with_time_interpolation(df, df.columns , '5min')
    df['date'] = pd.to_datetime(df['date'], unit='s')
    df['weekday'] = df.date.apply(lambda x: x.weekday())
    df['month'] = df.date.apply(lambda x: x.month)
    df['hour'] = df.date.apply(lambda x: x.hour)
    
    values = [
        site_dic['point_id'], site_dic['point']['pipe_info']['channel_shape'],
        site_dic['point']['pipe_info']['diameter'],
        site_dic['point']['group']['water_authority']['id'],
        site_dic['point']['group']['sector']['id']
    ]
    df[['point_id', 'channel_shape', 'diameter', 'water_authority',
        'sector']] = values

    return (df)

# %%
df = create_sectorial_dataframe(collectors)
# Out:
# 0it [00:00, ?it/s]
# getting info from 2045
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1543816800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1551307500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1573277400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1581095400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1588677900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2045&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# 1it [00:31, 31.08s/it]
# adding datafram to the sectorial dataframe
# getting info from 1531
# Kando - GET /api/data/fetch?point_id=1531&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1531&unit_id=&start=1512648240&end=&raw_data=
# creating a dataframe
# 2it [00:35, 22.97s/it]
# adding datafram to the sectorial dataframe
# getting info from 1545
# Kando - GET /api/data/fetch?point_id=1545&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1545&unit_id=&start=1509030120&end=&raw_data=
# 3it [00:37, 16.64s/it]
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1333
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1499289600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1507028100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1514664900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1527043800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1534543500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1542537000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1553383800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1560881700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1568372400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1575855600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1583436300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1592836800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1333&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# 4it [01:49, 33.37s/it]
# adding datafram to the sectorial dataframe
# getting info from 1561
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1530606000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1538062800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1545572700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1553721900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1561182300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1568617200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1576769400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1584392100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1591962300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1561&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# 5it [02:46, 40.49s/it]
# adding datafram to the sectorial dataframe
# getting info from 1332
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1500592800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1508546700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1516689600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1525740600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1533222900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1540712400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1548772500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1556246100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1563732000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1571226000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1579255500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1586923500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1332&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# 6it [03:59, 50.31s/it]
# adding datafram to the sectorial dataframe
# getting info from 2385
# Kando - GET /api/data/fetch?point_id=2385&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2385&unit_id=&start=None&end=&raw_data=
# 7it [04:01, 35.73s/it]
# No data about site 2385
# getting info from 2391
# Kando - GET /api/data/fetch?point_id=2391&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2391&unit_id=&start=None&end=&raw_data=
# 8it [04:03, 25.52s/it]
# No data about site 2391
# getting info from 2387
# Kando - GET /api/data/fetch?point_id=2387&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2387&unit_id=&start=None&end=&raw_data=
# 9it [04:04, 27.22s/it]
# No data about site 2387

# %%
df
# Out:
#             PH      EC    ORP  TEMPERATURE                date  weekday  \
# 0        6.900  1304.0 -467.0         28.4 2018-09-05 03:05:00        2
# 1        6.900  1312.0 -466.0         28.4 2018-09-05 03:10:00        2
# 2        6.800  1328.0 -466.0         28.3 2018-09-05 03:15:00        2
# 3        6.800  1336.0 -465.0         28.3 2018-09-05 03:20:00        2
# 4        6.800  1344.0 -465.0         28.3 2018-09-05 03:25:00        2
# ...        ...     ...    ...          ...                 ...      ...
# 1003582  1.544    96.0  359.0         23.9 2020-07-05 02:10:00        6
# 1003583  1.542    96.0  359.0         23.9 2020-07-05 02:20:00        6
# 1003584  1.541    96.0  359.0         24.0 2020-07-05 02:30:00        6
# 1003585  1.546    96.0  359.0         24.0 2020-07-05 02:40:00        6
# 1003586  1.547    96.0  360.0         23.9 2020-07-05 02:50:00        6
#
#          month  hour  point_id  channel_shape  diameter  water_authority  \
# 0            9     3      2045  circular_pipe     0.125               24
# 1            9     3      2045  circular_pipe     0.125               24
# 2            9     3      2045  circular_pipe     0.125               24
# 3            9     3      2045  circular_pipe     0.125               24
# 4            9     3      2045  circular_pipe     0.125               24
# ...        ...   ...       ...            ...       ...              ...
# 1003582      7     2      1332  circular_pipe     0.250               24
# 1003583      7     2      1332  circular_pipe     0.250               24
# 1003584      7     2      1332  circular_pipe     0.250               24
# 1003585      7     2      1332  circular_pipe     0.250               24
# 1003586      7     2      1332  circular_pipe     0.250               24
#
#          sector
# 0            48
# 1            48
# 2            48
# 3            48
# 4            48
# ...         ...
# 1003582      48
# 1003583      48
# 1003584      48
# 1003585      48
# 1003586      48
#
# [1003587 rows x 13 columns]

# %%
df.to_pickle("./gichon_collector.pkl")

# %%
df = pd.read_pickle("./gichon_collector.pkl")

# %%
df
# Out:
#             PH      EC    ORP  TEMPERATURE                date  weekday  \
# 0        6.900  1304.0 -467.0         28.4 2018-09-05 03:05:00        2
# 1        6.900  1312.0 -466.0         28.4 2018-09-05 03:10:00        2
# 2        6.800  1328.0 -466.0         28.3 2018-09-05 03:15:00        2
# 3        6.800  1336.0 -465.0         28.3 2018-09-05 03:20:00        2
# 4        6.800  1344.0 -465.0         28.3 2018-09-05 03:25:00        2
# ...        ...     ...    ...          ...                 ...      ...
# 1003582  1.544    96.0  359.0         23.9 2020-07-05 02:10:00        6
# 1003583  1.542    96.0  359.0         23.9 2020-07-05 02:20:00        6
# 1003584  1.541    96.0  359.0         24.0 2020-07-05 02:30:00        6
# 1003585  1.546    96.0  359.0         24.0 2020-07-05 02:40:00        6
# 1003586  1.547    96.0  360.0         23.9 2020-07-05 02:50:00        6
#
#          month  hour  point_id  channel_shape  diameter  water_authority  \
# 0            9     3      2045  circular_pipe     0.125               24
# 1            9     3      2045  circular_pipe     0.125               24
# 2            9     3      2045  circular_pipe     0.125               24
# 3            9     3      2045  circular_pipe     0.125               24
# 4            9     3      2045  circular_pipe     0.125               24
# ...        ...   ...       ...            ...       ...              ...
# 1003582      7     2      1332  circular_pipe     0.250               24
# 1003583      7     2      1332  circular_pipe     0.250               24
# 1003584      7     2      1332  circular_pipe     0.250               24
# 1003585      7     2      1332  circular_pipe     0.250               24
# 1003586      7     2      1332  circular_pipe     0.250               24
#
#          sector
# 0            48
# 1            48
# 2            48
# 3            48
# 4            48
# ...         ...
# 1003582      48
# 1003583      48
# 1003584      48
# 1003585      48
# 1003586      48
#
# [1003587 rows x 13 columns]

# %%
cols_for_matrix_profile = ['EC', 'PH', 'ORP', 'TEMPERATURE']
mps = create_matrix_profile_dictionary(df, cols_for_matrix_profile, m=36)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# /home/ron/anaconda3/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1667: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0b5e13c86994> in <module>
#       1 cols_for_matrix_profile = ['EC', 'PH', 'ORP', 'TEMPERATURE']
# ----> 2 mps = create_matrix_profile_dictionary(df, cols_for_matrix_profile, m=36)
#
# <ipython-input-1-c986aae346d0> in create_matrix_profile_dictionary(df, target_cols, m)
#       3     for col_ in tqdm(target_cols):
#       4         mps[f'mp_{col_}'] = stumpy.stump(df[f'{col_}'], m)
# ----> 5     mps['All_dimensions'] = stumpy.mstump(df[target_cols], m)
#       6     return (mps)
#
# ~/anaconda3/lib/python3.6/site-packages/stumpy/mstump.py in mstump(T, m, include, discords)
#     659         start + 1,
#     660         include,
# --> 661         discords,
#     662     )
#     663
#
# ~/anaconda3/lib/python3.6/site-packages/stumpy/mstump.py in _mstump(T, m, range_stop, excl_zone, M_T, Σ_T, QT, QT_first, μ_Q, σ_Q, k, range_start, include, discords)
#     551             D[start_row_idx:][::-1].sort(axis=0)
#     552         else:
# --> 553             D[start_row_idx:].sort(axis=0)
#     554
#     555         _compute_PI(d, idx, D, D_prime, range_start, P, I)
#
# KeyboardInterrupt:

# %%
a_file = open("colliectors_matrix_profile.json", "w")
json.dump(mps, a_file)
a_file.close()

# %%
[244,]
