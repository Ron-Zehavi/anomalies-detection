# %%
import pandas as pd
import json
from tqdm import tqdm
from kando import kando_client
# %run utils.ipynb

# %%
with open('key.json') as f:
    api_login = json.load(f)

url = "https://kando-staging.herokuapp.com"
client = kando_client.client(url, api_login['key'], api_login['secret'])

# %%
with open('sectors.json') as f:
    data = json.load(f)

# %%
len(data['399']['nodes'])
# Out:
# 117

# %%
def get_data_for_sectorial_motif_detection(site_dic):

    df = pd.DataFrame.from_dict(site_dic['samplings'], orient='index')[[
        'DateTime', 'PH', 'EC', 'ORP', 'TEMPERATURE'
    ]]
    df['date'] = df['DateTime']
    df['DateTime'] = pd.to_datetime(df['DateTime'], unit='s')
    df = df.set_index('DateTime')

    impute_nulls_with_time_interpolation(df, df.columns , '5min')
    df['date'] = pd.to_datetime(df['date'], unit='s')
    df['weekday'] = df.date.apply(lambda x: x.weekday())
    df['month'] = df.date.apply(lambda x: x.month)
    df['hour'] = df.date.apply(lambda x: x.hour)
    
    values = [
        site_dic['point_id'], site_dic['point']['pipe_info']['channel_shape'],
        site_dic['point']['pipe_info']['diameter'],
        site_dic['point']['group']['water_authority']['id'],
        site_dic['point']['group']['sector']['id']
    ]
    df[['point_id', 'channel_shape', 'diameter', 'water_authority',
        'sector']] = values

    return(df)

# %%
def create_sectorial_dataframe(sites_list, start_date=2016):
    for site in tqdm(sites_list):
        print(f'getting info from {site}')
        site_dic = client.get_all(point_id=site, start=start_date)            
        if len(site_dic['samplings'])>0:
            print(f'creating a dataframe')
            sector_tmp = get_data_for_sectorial_motif_detection(site_dic)
            print(f'adding datafram to the sectorial dataframe')
            if 'sector' not in locals():
                sector = sector_tmp
            else:
                sector = pd.concat([sector, sector_tmp])
        else:
            print(f'No data about site {site}')
    sector.reset_index(drop=True, inplace=True)
    return sector

# %%
df_hotels = create_sectorial_dataframe(data['399']['nodes'], start_date=2016)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
# getting info from 25
# Kando - GET /api/data/fetch?point_id=25&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=25&unit_id=&start=None&end=&raw_data=
# No data about site 25
# getting info from 39
# Kando - GET /api/data/fetch?point_id=39&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=39&unit_id=&start=None&end=&raw_data=
# No data about site 39
# getting info from 49
# Kando - GET /api/data/fetch?point_id=49&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=49&unit_id=&start=None&end=&raw_data=
# No data about site 49
# getting info from 50
# Kando - GET /api/data/fetch?point_id=50&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=50&unit_id=&start=None&end=&raw_data=
# No data about site 50
# getting info from 51
# Kando - GET /api/data/fetch?point_id=51&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=51&unit_id=&start=None&end=&raw_data=
# No data about site 51
# getting info from 52
# Kando - GET /api/data/fetch?point_id=52&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=52&unit_id=&start=None&end=&raw_data=
# No data about site 52
# getting info from 53
# Kando - GET /api/data/fetch?point_id=53&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=53&unit_id=&start=None&end=&raw_data=
# No data about site 53
# getting info from 54
# Kando - GET /api/data/fetch?point_id=54&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=54&unit_id=&start=None&end=&raw_data=
# No data about site 54
# getting info from 55
# Kando - GET /api/data/fetch?point_id=55&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=55&unit_id=&start=None&end=&raw_data=
# No data about site 55
# getting info from 59
# Kando - GET /api/data/fetch?point_id=59&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=59&unit_id=&start=None&end=&raw_data=
# No data about site 59
# getting info from 60
# Kando - GET /api/data/fetch?point_id=60&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=60&unit_id=&start=None&end=&raw_data=
# No data about site 60
# getting info from 165
# Kando - GET /api/data/fetch?point_id=165&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=165&unit_id=&start=None&end=&raw_data=
# No data about site 165
# getting info from 191
# Kando - GET /api/data/fetch?point_id=191&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=191&unit_id=&start=1488277260&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 207
# Kando - GET /api/data/fetch?point_id=207&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=207&unit_id=&start=None&end=&raw_data=
# No data about site 207
# getting info from 208
# Kando - GET /api/data/fetch?point_id=208&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=208&unit_id=&start=None&end=&raw_data=
# No data about site 208
# getting info from 209
# Kando - GET /api/data/fetch?point_id=209&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=209&unit_id=&start=None&end=&raw_data=
# No data about site 209
# getting info from 210
# Kando - GET /api/data/fetch?point_id=210&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=210&unit_id=&start=1537326000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 229
# Kando - GET /api/data/fetch?point_id=229&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=229&unit_id=&start=1482714000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=229&unit_id=&start=1523460600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=229&unit_id=&start=1531926900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=229&unit_id=&start=1539054000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 255
# Kando - GET /api/data/fetch?point_id=255&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=255&unit_id=&start=None&end=&raw_data=
# No data about site 255
# getting info from 262
# Kando - GET /api/data/fetch?point_id=262&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=262&unit_id=&start=None&end=&raw_data=
# No data about site 262
# getting info from 263
# Kando - GET /api/data/fetch?point_id=263&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=263&unit_id=&start=None&end=&raw_data=
# No data about site 263
# getting info from 267
# Kando - GET /api/data/fetch?point_id=267&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=267&unit_id=&start=None&end=&raw_data=
# No data about site 267
# getting info from 270
# Kando - GET /api/data/fetch?point_id=270&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=270&unit_id=&start=None&end=&raw_data=
# No data about site 270
# getting info from 273
# Kando - GET /api/data/fetch?point_id=273&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=273&unit_id=&start=None&end=&raw_data=
# No data about site 273
# getting info from 301
# Kando - GET /api/data/fetch?point_id=301&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=301&unit_id=&start=None&end=&raw_data=
# No data about site 301
# getting info from 404
# Kando - GET /api/data/fetch?point_id=404&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=404&unit_id=&start=None&end=&raw_data=
# No data about site 404
# getting info from 405
# Kando - GET /api/data/fetch?point_id=405&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=405&unit_id=&start=None&end=&raw_data=
# No data about site 405
# getting info from 406
# Kando - GET /api/data/fetch?point_id=406&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=406&unit_id=&start=None&end=&raw_data=
# No data about site 406
# getting info from 407
# Kando - GET /api/data/fetch?point_id=407&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=407&unit_id=&start=None&end=&raw_data=
# No data about site 407
# getting info from 408
# Kando - GET /api/data/fetch?point_id=408&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=408&unit_id=&start=None&end=&raw_data=
# No data about site 408
# getting info from 409
# Kando - GET /api/data/fetch?point_id=409&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=409&unit_id=&start=None&end=&raw_data=
# No data about site 409
# getting info from 410
# Kando - GET /api/data/fetch?point_id=410&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=410&unit_id=&start=None&end=&raw_data=
# No data about site 410
# getting info from 411
# Kando - GET /api/data/fetch?point_id=411&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=411&unit_id=&start=None&end=&raw_data=
# No data about site 411
# getting info from 412
# Kando - GET /api/data/fetch?point_id=412&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=412&unit_id=&start=None&end=&raw_data=
# No data about site 412
# getting info from 413
# Kando - GET /api/data/fetch?point_id=413&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=413&unit_id=&start=None&end=&raw_data=
# No data about site 413
# getting info from 414
# Kando - GET /api/data/fetch?point_id=414&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=414&unit_id=&start=None&end=&raw_data=
# No data about site 414
# getting info from 415
# Kando - GET /api/data/fetch?point_id=415&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=415&unit_id=&start=None&end=&raw_data=
# No data about site 415
# getting info from 416
# Kando - GET /api/data/fetch?point_id=416&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=416&unit_id=&start=None&end=&raw_data=
# No data about site 416
# getting info from 417
# Kando - GET /api/data/fetch?point_id=417&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=417&unit_id=&start=None&end=&raw_data=
# No data about site 417
# getting info from 418
# Kando - GET /api/data/fetch?point_id=418&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=418&unit_id=&start=None&end=&raw_data=
# No data about site 418
# getting info from 419
# Kando - GET /api/data/fetch?point_id=419&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=419&unit_id=&start=None&end=&raw_data=
# No data about site 419
# getting info from 435
# Kando - GET /api/data/fetch?point_id=435&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=435&unit_id=&start=None&end=&raw_data=
# No data about site 435
# getting info from 436
# Kando - GET /api/data/fetch?point_id=436&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=436&unit_id=&start=None&end=&raw_data=
# No data about site 436
# getting info from 449
# Kando - GET /api/data/fetch?point_id=449&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=449&unit_id=&start=None&end=&raw_data=
# No data about site 449
# getting info from 480
# Kando - GET /api/data/fetch?point_id=480&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=480&unit_id=&start=None&end=&raw_data=
# No data about site 480
# getting info from 482
# Kando - GET /api/data/fetch?point_id=482&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=482&unit_id=&start=None&end=&raw_data=
# No data about site 482
# getting info from 483
# Kando - GET /api/data/fetch?point_id=483&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=483&unit_id=&start=None&end=&raw_data=
# No data about site 483
# getting info from 484
# Kando - GET /api/data/fetch?point_id=484&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=484&unit_id=&start=None&end=&raw_data=
# No data about site 484
# getting info from 538
# Kando - GET /api/data/fetch?point_id=538&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=538&unit_id=&start=None&end=&raw_data=
# No data about site 538
# getting info from 601
# Kando - GET /api/data/fetch?point_id=601&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=601&unit_id=&start=None&end=&raw_data=
# No data about site 601
# getting info from 645
# Kando - GET /api/data/fetch?point_id=645&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=645&unit_id=&start=None&end=&raw_data=
# No data about site 645
# getting info from 740
# Kando - GET /api/data/fetch?point_id=740&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=740&unit_id=&start=None&end=&raw_data=
# No data about site 740
# getting info from 748
# Kando - GET /api/data/fetch?point_id=748&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=748&unit_id=&start=None&end=&raw_data=
# No data about site 748
# getting info from 750
# Kando - GET /api/data/fetch?point_id=750&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=750&unit_id=&start=None&end=&raw_data=
# No data about site 750
# getting info from 751
# Kando - GET /api/data/fetch?point_id=751&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=751&unit_id=&start=None&end=&raw_data=
# No data about site 751
# getting info from 752
# Kando - GET /api/data/fetch?point_id=752&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=752&unit_id=&start=None&end=&raw_data=
# No data about site 752
# getting info from 759
# Kando - GET /api/data/fetch?point_id=759&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=759&unit_id=&start=None&end=&raw_data=
# No data about site 759
# getting info from 902
# Kando - GET /api/data/fetch?point_id=902&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=902&unit_id=&start=None&end=&raw_data=
# No data about site 902
# getting info from 904
# Kando - GET /api/data/fetch?point_id=904&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=904&unit_id=&start=None&end=&raw_data=
# No data about site 904
# getting info from 908
# Kando - GET /api/data/fetch?point_id=908&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=908&unit_id=&start=None&end=&raw_data=
# No data about site 908
# getting info from 909
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=1560038100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=1567536900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=1575035700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=1582524000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=909&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 911
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1534014600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1557489300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1565681700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1573173900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1580658300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=911&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 918
# Kando - GET /api/data/fetch?point_id=918&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=918&unit_id=&start=1541121000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=918&unit_id=&start=1554951600&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 919
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1541056500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1548914700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1556464200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1564430400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1571859900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1579326300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1591711200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=919&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 922
# Kando - GET /api/data/fetch?point_id=922&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=922&unit_id=&start=None&end=&raw_data=
# No data about site 922
# getting info from 924
# Kando - GET /api/data/fetch?point_id=924&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=924&unit_id=&start=None&end=&raw_data=
# No data about site 924
# getting info from 925
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=1563622200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=1571586600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=1578933600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=1586257800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=925&unit_id=&start=1593921840&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 936
# Kando - GET /api/data/fetch?point_id=936&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=936&unit_id=&start=None&end=&raw_data=
# No data about site 936
# getting info from 937
# Kando - GET /api/data/fetch?point_id=937&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=937&unit_id=&start=1541323200&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 938
# Kando - GET /api/data/fetch?point_id=938&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=938&unit_id=&start=None&end=&raw_data=
# No data about site 938
# getting info from 939
# Kando - GET /api/data/fetch?point_id=939&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=939&unit_id=&start=None&end=&raw_data=
# No data about site 939
# getting info from 958
# Kando - GET /api/data/fetch?point_id=958&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=958&unit_id=&start=None&end=&raw_data=
# No data about site 958
# getting info from 959
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1489284300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1498078200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1513467000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1520833800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1529707800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1537066500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1550088060&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=959&unit_id=&start=1552901040&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 962
# Kando - GET /api/data/fetch?point_id=962&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=962&unit_id=&start=None&end=&raw_data=
# No data about site 962
# getting info from 964
# Kando - GET /api/data/fetch?point_id=964&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=964&unit_id=&start=None&end=&raw_data=
# No data about site 964
# getting info from 965
# Kando - GET /api/data/fetch?point_id=965&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=965&unit_id=&start=None&end=&raw_data=
# No data about site 965
# getting info from 971
# Kando - GET /api/data/fetch?point_id=971&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=971&unit_id=&start=None&end=&raw_data=
# No data about site 971
# getting info from 975
# Kando - GET /api/data/fetch?point_id=975&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=975&unit_id=&start=None&end=&raw_data=
# No data about site 975
# getting info from 979
# Kando - GET /api/data/fetch?point_id=979&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=979&unit_id=&start=None&end=&raw_data=
# No data about site 979
# getting info from 980
# Kando - GET /api/data/fetch?point_id=980&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=980&unit_id=&start=None&end=&raw_data=
# No data about site 980
# getting info from 981
# Kando - GET /api/data/fetch?point_id=981&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=981&unit_id=&start=None&end=&raw_data=
# No data about site 981
# getting info from 986
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1511989800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1521858300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1529405700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1537955700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1545737400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=986&unit_id=&start=1551974400&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 993
# Kando - GET /api/data/fetch?point_id=993&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=993&unit_id=&start=None&end=&raw_data=
# No data about site 993
# getting info from 1046
# Kando - GET /api/data/fetch?point_id=1046&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1046&unit_id=&start=None&end=&raw_data=
# No data about site 1046
# getting info from 1059
# Kando - GET /api/data/fetch?point_id=1059&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1059&unit_id=&start=None&end=&raw_data=
# No data about site 1059
# getting info from 1060
# Kando - GET /api/data/fetch?point_id=1060&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1060&unit_id=&start=None&end=&raw_data=
# No data about site 1060
# getting info from 1063
# Kando - GET /api/data/fetch?point_id=1063&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1063&unit_id=&start=None&end=&raw_data=
# No data about site 1063
# getting info from 1069
# Kando - GET /api/data/fetch?point_id=1069&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1069&unit_id=&start=None&end=&raw_data=
# No data about site 1069
# getting info from 1081
# Kando - GET /api/data/fetch?point_id=1081&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1081&unit_id=&start=None&end=&raw_data=
# No data about site 1081
# getting info from 1082
# Kando - GET /api/data/fetch?point_id=1082&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1082&unit_id=&start=None&end=&raw_data=
# No data about site 1082
# getting info from 1089
# Kando - GET /api/data/fetch?point_id=1089&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1089&unit_id=&start=None&end=&raw_data=
# No data about site 1089
# getting info from 1091
# Kando - GET /api/data/fetch?point_id=1091&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1091&unit_id=&start=None&end=&raw_data=
# No data about site 1091
# getting info from 1096
# Kando - GET /api/data/fetch?point_id=1096&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1096&unit_id=&start=None&end=&raw_data=
# No data about site 1096
# getting info from 1104
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1514648700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1522056300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1529551500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1537031700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1546094700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1553846100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1561323000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1568812500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1577225700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1586415900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1104&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1115
# Kando - GET /api/data/fetch?point_id=1115&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1115&unit_id=&start=None&end=&raw_data=
# No data about site 1115
# getting info from 1125
# Kando - GET /api/data/fetch?point_id=1125&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1125&unit_id=&start=None&end=&raw_data=
# No data about site 1125
# getting info from 1138
# Kando - GET /api/data/fetch?point_id=1138&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1138&unit_id=&start=1541044500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1138&unit_id=&start=1548745500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1138&unit_id=&start=1554951600&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1144
# Kando - GET /api/data/fetch?point_id=1144&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1144&unit_id=&start=None&end=&raw_data=
# No data about site 1144
# getting info from 1158
# Kando - GET /api/data/fetch?point_id=1158&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1158&unit_id=&start=None&end=&raw_data=
# No data about site 1158
# getting info from 1166
# Kando - GET /api/data/fetch?point_id=1166&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1166&unit_id=&start=None&end=&raw_data=
# No data about site 1166
# getting info from 1276
# Kando - GET /api/data/fetch?point_id=1276&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1276&unit_id=&start=1502087100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1276&unit_id=&start=1504558800&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1372
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1501497000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1510362900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1519895400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1527355200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1534841700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1542314100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1553917500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1562174700&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1569621300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1577118000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1584358800&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1372&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1518
# Kando - GET /api/data/fetch?point_id=1518&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1518&unit_id=&start=None&end=&raw_data=
# No data about site 1518
# getting info from 1519
# Kando - GET /api/data/fetch?point_id=1519&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1519&unit_id=&start=None&end=&raw_data=
# No data about site 1519
# getting info from 1560
# Kando - GET /api/data/fetch?point_id=1560&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1560&unit_id=&start=1517027100&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1560&unit_id=&start=1524503400&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1560&unit_id=&start=1534757880&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1574
# Kando - GET /api/data/fetch?point_id=1574&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1574&unit_id=&start=None&end=&raw_data=
# No data about site 1574
# getting info from 1642
# Kando - GET /api/data/fetch?point_id=1642&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1642&unit_id=&start=None&end=&raw_data=
# No data about site 1642
# getting info from 1645
# Kando - GET /api/data/fetch?point_id=1645&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1645&unit_id=&start=1544971620&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1645&unit_id=&start=1547537820&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1660
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1524126600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1531461600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1539253500&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1547907900&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1555737000&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1563189300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1570630200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1578273300&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1585548600&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1593001200&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1660&unit_id=&start=1593918000&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 1766
# Kando - GET /api/data/fetch?point_id=1766&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1766&unit_id=&start=None&end=&raw_data=
# No data about site 1766
# getting info from 1977
# Kando - GET /api/data/fetch?point_id=1977&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1977&unit_id=&start=None&end=&raw_data=
# No data about site 1977
# getting info from 1978
# Kando - GET /api/data/fetch?point_id=1978&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=1978&unit_id=&start=None&end=&raw_data=
# No data about site 1978
# getting info from 2403
# Kando - GET /api/data/fetch?point_id=2403&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2403&unit_id=&start=None&end=&raw_data=
# No data about site 2403
# getting info from 2406
# Kando - GET /api/data/fetch?point_id=2406&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2406&unit_id=&start=1593928800&end=&raw_data=
# creating a dataframe
# adding datafram to the sectorial dataframe
# getting info from 2778
# Kando - GET /api/data/fetch?point_id=2778&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=2778&unit_id=&start=None&end=&raw_data=
# No data about site 2778
# getting info from 3488
# Kando - GET /api/data/fetch?point_id=3488&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=3488&unit_id=&start=None&end=&raw_data=
# No data about site 3488
# getting info from 4046
# Kando - GET /api/data/fetch?point_id=4046&unit_id=&start=2016&end=&raw_data=
# Kando - GET /api/data/fetch?point_id=4046&unit_id=&start=None&end=&raw_data=
# No data about site 4046

# %%
df_hotels
# Out:
#             PH      EC    ORP  TEMPERATURE                date  weekday  \
# 0        5.900  2232.0  -43.0         24.0 2017-02-01 08:32:00        2
# 1        5.900  2144.0  -46.0         25.0 2017-02-01 08:35:00        2
# 2        5.800  2088.0  -45.0         25.0 2017-02-01 08:40:00        2
# 3        5.800  2080.0  -45.0         25.0 2017-02-01 08:41:00        2
# 4        5.700  2000.0  -45.0         25.0 2017-02-01 08:44:00        2
# ...        ...     ...    ...          ...                 ...      ...
# 2044560  3.567     0.0  159.0         31.7 2020-07-05 05:40:00        6
# 2044561  3.791     0.0  157.0         31.7 2020-07-05 05:45:00        6
# 2044562  3.454     0.0  170.0         31.6 2020-07-05 05:50:00        6
# 2044563  3.284     0.0  175.0         31.5 2020-07-05 05:55:00        6
# 2044564  3.324     0.0  177.0         31.5 2020-07-05 06:00:00        6
#
#          month  hour  point_id  channel_shape  diameter  water_authority  \
# 0            2     8       191  circular_pipe       0.2                3
# 1            2     8       191  circular_pipe       0.2                3
# 2            2     8       191  circular_pipe       0.2                3
# 3            2     8       191  circular_pipe       0.2                3
# 4            2     8       191  circular_pipe       0.2                3
# ...        ...   ...       ...            ...       ...              ...
# 2044560      7     5      2406  circular_pipe       0.5                7
# 2044561      7     5      2406  circular_pipe       0.5                7
# 2044562      7     5      2406  circular_pipe       0.5                7
# 2044563      7     5      2406  circular_pipe       0.5                7
# 2044564      7     6      2406  circular_pipe       0.5                7
#
#          sector
# 0           399
# 1           399
# 2           399
# 3           399
# 4           399
# ...         ...
# 2044560     399
# 2044561     399
# 2044562     399
# 2044563     399
# 2044564     399
#
# [2044565 rows x 13 columns]

# %%
df_hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1953387 entries, 0 to 2044564
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PH               float64
#  1   EC               float64
#  2   ORP              float64
#  3   TEMPERATURE      float64
#  4   date             datetime64[ns]
#  5   weekday          int64
#  6   month            int64
#  7   hour             int64
#  8   point_id         int64
#  9   channel_shape    object
#  10  diameter         float64
#  11  water_authority  int64
#  12  sector           int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(1)
# memory usage: 208.6+ MB

# %%
df_hotels.isna().sum()
# Out:
# PH                 58700
# EC                 66309
# ORP                67076
# TEMPERATURE        66864
# date                   0
# weekday                0
# month                  0
# hour                   0
# point_id               0
# channel_shape          0
# diameter               0
# water_authority        0
# sector                 0
# dtype: int64

# %%
df_hotels.dropna(inplace=True)

# %%
df_hotels.to_pickle("./Israel_hotels_sector.pkl")
